# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/jennybc/gapminder/master/inst/extdata/gapminder.tsv', sep='\t')

# %%
print(df.head())
print(df.info())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB
# None

# %%
df.shape 
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165876
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %% [markdown]
# # Q1. pop이 평균보다 인구가 높은 국가의 1970년대 데이터필터링하고, continent, country, pop, gdpPercap만 출력

# %%
## 1970년대 찾기
df['year'].unique()
# 1972, 1977 발견
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
df1 = df[(df['pop']>=df['pop'].mean()) & (df['year'].isin([1972, 1977]))]
df1
# Out:
#              country continent  year   lifeExp        pop     gdpPercap
# 100       Bangladesh      Asia  1972  45.25200   70759295    630.233627
# 101       Bangladesh      Asia  1977  46.92300   80428306    659.877232
# 172           Brazil  Americas  1972  59.50400  100840058   4985.711467
# 173           Brazil  Americas  1977  61.48900  114313951   6660.118654
# 292            China      Asia  1972  63.11888  862030000    676.900092
# 293            China      Asia  1977  63.96736  943455000    741.237470
# 460            Egypt    Africa  1972  51.13700   34807417   2024.008147
# 461            Egypt    Africa  1977  53.31900   38783863   2785.493582
# 508         Ethiopia    Africa  1972  43.51500   30770372    566.243944
# 509         Ethiopia    Africa  1977  44.51000   34617799    556.808383
# 532           France    Europe  1972  72.38000   51732000  16107.191710
# 533           France    Europe  1977  73.83000   53165019  18292.635140
# ...

# %%
df2 = df1[['continent','country','pop','gdpPercap']]

# %% [markdown]
# # Q2. Q1에서 추출한 df에서, 한국, 중국, 일본의 데이터를 추출하고, 국가별로 그룹화해서 인구수 평균을 구하라

# %%
df1['country'].unique() # 국가명 확인 Korea,Rep. , Japan, China
# Out:
# array(['Bangladesh', 'Brazil', 'China', 'Egypt', 'Ethiopia', 'France',
#        'Germany', 'India', 'Indonesia', 'Iran', 'Italy', 'Japan',
#        'Korea, Rep.', 'Mexico', 'Myanmar', 'Nigeria', 'Pakistan',
#        'Philippines', 'Poland', 'Spain', 'Thailand', 'Turkey',
#        'United Kingdom', 'United States', 'Vietnam'], dtype=object)

# %%
east_asia = ['Korea, Rep.', 'Japan', 'China']
df2[df2['country'].isin(east_asia)]
# Out:
#     continent      country        pop     gdpPercap
# 292      Asia        China  862030000    676.900092
# 293      Asia        China  943455000    741.237470
# 796      Asia        Japan  107188273  14778.786360
# 797      Asia        Japan  113872473  16610.377010
# 844      Asia  Korea, Rep.   33505000   3030.876650
# 845      Asia  Korea, Rep.   36436000   4657.221020

# %%
df2[df2['country'].isin(east_asia)].groupby(['country']).mean()['pop']
# Out:
# country
# China          902742500.0
# Japan          110530373.0
# Korea, Rep.     34970500.0
# Name: pop, dtype: float64

# %% [markdown]
# ## Q3. Q2 작성한 내용 바탕으로, 3개국의 1970년대 인구수를 막대그래프로 작성

# %%
df['year'].unique() # 70년대 두 개
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
df3 = df2[df2['country'].isin(east_asia)].groupby('country').mean()['pop']

# %%
df3.plot(kind = 'bar', title = "1970's population in east_asia", color = ['red','steelblue','green'])
plt.show()

# %% [markdown]
# ## Police.csv 연습!

# %%
import pandas as pd 

df = pd.read_csv('police.csv')
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# ## Questions
#
# - What is the average age of drivers that were stopped ?
# - What is the minimum age of the drivers that were stopped?
# - What is the gender-wise distribution of the drivers that were stopped?
# - Display month-wise distribution of the traffic stops.
# - Display race-wise distribution of the traffic stops.
# - Display violations for what traffic stops happened.
# - In what percentage of the cases the search was conducted?
# - Display the different outcome of the traffic.
# - In how many cases, arrest was conducted?
# - How many stops were drug related?
# - Display the different duration of the traffic stops.

# %%
#1. what is the avg age of drivers that were stopped ?

import numpy as np
import seaborn as sns
import warnings

# %%
df.describe()
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %%
new_df = df.drop(['county_name','driver_age_raw','violation_raw'], axis = 'columns')

# %%
new_df.head()
# Out:
#     stop_date stop_time driver_gender  driver_age driver_race violation  \
# 0  2005-01-02     01:55             M        20.0       White  Speeding
# 1  2005-01-18     08:15             M        40.0       White  Speeding
# 2  2005-01-23     23:15             M        33.0       White  Speeding
# 3  2005-02-20     17:15             M        19.0       White     Other
# 4  2005-03-14     10:00             F        21.0       White  Speeding
#
#    search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0             False         NaN       Citation       False      0-15 Min
# 1             False         NaN       Citation       False      0-15 Min
# 2             False         NaN       Citation       False      0-15 Min
# 3             False         NaN  Arrest Driver        True     16-30 Min
# 4             False         NaN       Citation       False      0-15 Min
#
#    drugs_related_stop
# 0               False
# 1               False
# 2               False
# ...

# %%
new_df.dropna(axis = 0, how = 'any', thresh = 6, inplace = True) # NaN이 아닌 값이 6개 이상이면 놔두고, 아니면 삭제 (값이 6개 이하만 있으면 그 행 걍 삭제)
new_df
# Out:
#         stop_date stop_time driver_gender  driver_age driver_race  \
# 0      2005-01-02     01:55             M        20.0       White
# 1      2005-01-18     08:15             M        40.0       White
# 2      2005-01-23     23:15             M        33.0       White
# 3      2005-02-20     17:15             M        19.0       White
# 4      2005-03-14     10:00             F        21.0       White
# ...           ...       ...           ...         ...         ...
# 91736  2015-12-31     20:27             M        29.0       White
# 91737  2015-12-31     20:35             F        33.0       White
# 91738  2015-12-31     20:45             M        23.0       White
# 91739  2015-12-31     21:42             M        22.0       White
# 91740  2015-12-31     22:46             M        56.0    Hispanic
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# ...

# %%
index = new_df[new_df['driver_age'].isnull()].index # driver age null 은 삭제

# %%
new_df.drop(index, inplace = True) # index 위에 조건 삭제

# %%
new_df.to_csv('cleaned.csv', index = False)

# %%
cln_df = pd.read_csv('cleaned.csv')

# %%
cln_df['stop_date'] = pd.to_datetime(cln_df['stop_date'])
cln_df.sort_values(by = 'stop_date').reset_index(drop = True)
# Out:
#        stop_date stop_time driver_gender  driver_age driver_race  \
# 0     2005-01-02     01:55             M        20.0       White
# 1     2005-01-18     08:15             M        40.0       White
# 2     2005-01-23     23:15             M        33.0       White
# 3     2005-02-20     17:15             M        19.0       White
# 4     2005-03-14     10:00             F        21.0       White
# ...          ...       ...           ...         ...         ...
# 86110 2015-12-31     00:01             M        49.0       White
# 86111 2015-12-31     00:00             F        22.0       White
# 86112 2015-12-31     21:42             M        22.0       White
# 86113 2015-12-31     09:17             F        20.0       White
# 86114 2015-12-31     22:46             M        56.0    Hispanic
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# ...

# %%
print('\033[1m','Average age of drivers that were stopped is',cln_df['driver_age'].mean(),'.''\033[0m')
print('\033[1m','Minimum age of the driver that was stopped is',cln_df['driver_age'].min(),'.','\033[0m')
print('\033[1m','Maximum age of the driver that was stopped is',cln_df['driver_age'].max(),'.','\033[0m')
# Out:
#  Average age of drivers that were stopped is 34.01165882831098 .
#  Minimum age of the driver that was stopped is 15.0 .
#  Maximum age of the driver that was stopped is 99.0 .

# %%
male = (cln_df['driver_gender'].value_counts()[0]/cln_df['driver_gender'].count())*100
female = (cln_df['driver_gender'].value_counts()[1]/cln_df['driver_gender'].count())*100

# %%
print('\033[1m','Total of', cln_df['driver_gender'].value_counts()[0],'males were stopped during traffic stops which is ',round(male,2),'% of total stops.','\033[0m')
print('\033[1m','Total of', cln_df['driver_gender'].value_counts()[1],'females were stopped during traffic stops which is ',round(female,2),'% of total stops.','\033[0m')
# Out:
#  Total of 62649 males were stopped during traffic stops which is  72.75 % of total stops.
#  Total of 23464 females were stopped during traffic stops which is  27.25 % of total stops.

# %%
cln_df['month_year'] = cln_df['stop_date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
df_trend = pd.DataFrame(cln_df.groupby('month_year').count().reset_index())

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,6))
plt.plot(df_trend['month_year'],df_trend['driver_age'], color='#b80045')
plt.xticks(rotation='vertical', size=7)
print('\033[1m','Below is a graph that shows month-wise distribution of traffic stops along the years from',cln_df['month_year'].min(),"to",cln_df['month_year'].max(),'.','\033[0m')
plt.show()
# Out:
#  Below is a graph that shows month-wise distribution of traffic stops along the years from 2005-01 to 2015-12 .
