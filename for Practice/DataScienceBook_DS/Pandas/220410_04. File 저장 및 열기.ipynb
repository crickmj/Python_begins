# %% [markdown]
# # 파일 저장 및 열기

# %%
import pandas as pd
data = {
    '이름' : ['채치수','정대만','송태섭','서태웅','강백호','변덕규','황태산','윤대협'],
    '학교' : ['북산고','북산고','북산고','북산고','북산고', '능남고','능남고','능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 95],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '','','C','PYTHON','C#']
}
df = pd.DataFrame(data, index=['1번','2번','3번','4번','5번','6번','7번','8번']) 
df.index.name = '지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   95  95  95          C#

# %% [markdown]
# ## 저장하기
# ### csv 파일로 저장

# %%
df.to_csv('score.csv') # encoding 깨지면, encoding = 'utf-8-sig' 추가 
# or index = False 하면, 이름부터 추가됨

# %% [markdown]
# ### txt 파일로 저장

# %%
df.to_csv('score.txt', sep='\t') # tsv (tap seperated 로 표시 )

# %% [markdown]
# ### 엑셀로 저장

# %%
df.to_excel('score.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/minjoonlim/Desktop/python workspace/mjmj/for Practice/Python_data_ws/Pandas/220410_04. File 저장 및 열기.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/minjoonlim/Desktop/python%20workspace/mjmj/for%20Practice/Python_data_ws/Pandas/220410_04.%20File%20%EC%A0%80%EC%9E%A5%20%EB%B0%8F%20%EC%97%B4%EA%B8%B0.ipynb#ch0000012?line=0'>1</a> df.to_excel('score.xlsx')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:2357, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
# ...

# %% [markdown]
# ## 열기
# ### csv 파일 열기

# %%
df = pd.read_csv('score.csv')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   95  95  95          C#

# %%
df = pd.read_csv('score.csv', skiprows=1) # 1개 ㄱㅁㅈ무시
df
# Out:
#    1번  채치수  북산고  197   90   85  100  95  85.1      Python
# 0  2번  정대만  북산고  184   40   35   50  55    25        Java
# 1  3번  송태섭  북산고  168   80   75   70  80    75  Javascript
# 2  4번  서태웅  북산고  187   40   60   70  75    80         NaN
# 3  5번  강백호  북산고  188   15   20   10  35    10         NaN
# 4  6번  변덕규  능남고  202   80  100   95  85    80           C
# 5  7번  황태산  능남고  188   55   65   45  40    35      PYTHON
# 6  8번  윤대협  능남고  190  100   85   95  95    95          C#

# %%
df = pd.read_csv('score.csv', skiprows=[1,3,5])
df
# Out:
#   지원번호   이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 0   2번  정대만  북산고  184   40   35  50  55  25    Java
# 1   4번  서태웅  북산고  187   40   60  70  75  80     NaN
# 2   6번  변덕규  능남고  202   80  100  95  85  80       C
# 3   7번  황태산  능남고  188   55   65  45  40  35  PYTHON
# 4   8번  윤대협  능남고  190  100   85  95  95  95      C#

# %%
df = pd.read_csv('score.csv', nrows=4)
df
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197  90  85  100  95  85      Python
# 1   2번  정대만  북산고  184  40  35   50  55  25        Java
# 2   3번  송태섭  북산고  168  80  75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187  40  60   70  75  80         NaN

# %%
df = pd.read_csv('score.csv', skiprows = 2, nrows = 4) # 처음 2개 무시하고, 이후 4개 받아옴
df
# Out:
#    2번  정대만  북산고  184  40   35  50  55  25        Java
# 0  3번  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1  4번  서태웅  북산고  187  40   60  70  75  80         NaN
# 2  5번  강백호  북산고  188  15   20  10  35  10         NaN
# 3  6번  변덕규  능남고  202  80  100  95  85  80           C

# %% [markdown]
# ### tx 파일 불러오기

# %%
df = pd.read_csv('score.txt', sep='\t')
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   95  95  95          C#

# %%
df = pd.read_csv('score.txt', sep='\t', index_col = '지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   95  95  95          C#

# %%
df = pd.read_csv('score.txt', sep='\t')
df.set_index('지원번호', inplace=False)
df
# Out:
#   지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0   1번  채치수  북산고  197   90   85  100  95  85      Python
# 1   2번  정대만  북산고  184   40   35   50  55  25        Java
# 2   3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3   4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 4   5번  강백호  북산고  188   15   20   10  35  10         NaN
# 5   6번  변덕규  능남고  202   80  100   95  85  80           C
# 6   7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7   8번  윤대협  능남고  190  100   85   95  95  95          C#
