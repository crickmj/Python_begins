# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프 통해 데이터 시각화 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 01. 그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]

plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show() # title처럼 불필요한 데이터 안나오게끔

# %% [markdown]
# ## title 설정

# %%
plt.plot(x,y)
plt.title("Line graph")
# Out:
# Text(0.5, 1.0, 'Line graph')

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기 
matplotlib.rcParams['axes.unicode_minus'] = False # 한글폰트 사용할 때 - 가 깨지는 현상 해결

# %%
import matplotlib.font_manager as fm # 폰트 어떤거 있는지 확인
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXSizeFourSym',
#  'cmtt10',
#  'STIXSizeTwoSym',
#  'cmex10',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'cmsy10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmr10',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'Noto Sans Myanmar',
#  'Noto Sans Old Italic',
#  'Courier New',
#  'Malayalam MN',
#  'Noto Sans Mahajani',
#  'Zapfino',
#  'Lao Sangam MN',
#  'Marion',
#  'Wingdings 2',
#  'Palatino',
#  'Georgia',
#  'Khmer MN',
#  'Noto Sans Coptic',
# ...

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1,0,1], [-5,-1,2]) # - 깨짐
