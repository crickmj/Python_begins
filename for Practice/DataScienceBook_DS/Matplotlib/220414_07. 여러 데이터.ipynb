# %% [markdown]
# # 07 여러 데이터

# %%
import matplotlib.pyplot as plt 
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기 
matplotlib.rcParams['axes.unicode_minus'] = False # 한글폰트 사용할 때 - 가 깨지는 현상 해결

# %%
x = [1,2,3]
y = [2,4,8]

# %% [markdown]
# ## COVID-19 백신 종류별 접종 인구

# %%
days = [1,2,3] # 10월 1일, 2일, 3일
az = [2,4,8] # 1일 - 3일 2,4,8만명 접종자 
pfizer = [5,1,3] 
moderna = [1,2,5]

plt.plot(days, az)
plt.plot(days, pfizer)
plt.plot(days, moderna)

# %%
plt.plot(days, az, label = 'az')
plt.plot(days, pfizer, label = 'pfizer', marker = 'o', ls = '--')
plt.plot(days, moderna, label = 'moderna', marker = 's', ls = '-.')

plt.legend()

# %%
plt.plot(days, az, label = 'az')
plt.plot(days, pfizer, label = 'pfizer', marker = 'o', ls = '--')
plt.plot(days, moderna, label = 'moderna', marker = 's', ls = '-.')

plt.legend(ncol = 3) # 컬럼 몇 개로 해서 할건가,, --> 3으로 하면 3컬럼으로 되서 가로로 될 거임
